# %%
# !pip install "torch==1.4" "torchvision==0.5.0"

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from fastai.vision import *

# %% [markdown]
# ### Data

# %%
path = Path('/content/drive/My Drive/X-Ray Image DataSet - Binary')

# %%
np.random.seed(41)
data = ImageDataBunch.from_folder(path, train='train', valid ="test",
        ds_tfms=get_transforms(), size=(256,256), bs=32, num_workers=4).normalize()

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Covid-19', 'No_findings'], 2, 500, 125)

# %%
print("Number of examples in training:", len(data.train_ds))
print("Number of examples in validation:", len(data.valid_ds))
# Out:
# Number of examples in training: 500
# Number of examples in validation: 125

# %%
xb,yb = data.one_batch()
xb.shape,yb.shape
# Out:
# (torch.Size([32, 3, 256, 256]), torch.Size([32]))

# %%
#Sample images from the dataset
data.show_batch(rows=3, figsize=(10,10))

# %% [markdown]
# ## DarkCovidNet (modified Darknet model)

# %%
def conv_block(ni, nf, size=3, stride=1):
    for_pad = lambda s: s if s > 2 else 3
    return nn.Sequential(
        nn.Conv2d(ni, nf, kernel_size=size, stride=stride,
                  padding=(for_pad(size) - 1)//2, bias=False), 
        nn.InstanceNorm2d(nf),
        nn.LeakyReLU(negative_slope=0.1, inplace=True),
        nn.BatchNorm2d(nf)   
    )

# %%
def triple_conv(ni, nf):
    return nn.Sequential(
        conv_block(ni, nf),
        conv_block(nf, ni, size=1),  
        conv_block(ni, nf)
    )

# %%
def maxpooling():
    return nn.MaxPool2d(2, stride=2)

# %%
model = nn.Sequential(
    conv_block(3, 8),
    maxpooling(),
    conv_block(8, 16),
    maxpooling(),
    triple_conv(16, 32),
    maxpooling(),
    triple_conv(32, 64),
    maxpooling(),
    triple_conv(64, 128),
    maxpooling(),
    triple_conv(128, 256),
    conv_block(256, 128, size=1),
    conv_block(128, 256),
    conv_layer(256, 2),
    Flatten(),
    nn.Linear(338, 2)
)

# %%
learn = Learner(data, model, loss_func = nn.CrossEntropyLoss(), metrics=accuracy)

# %%
print(learn.summary())
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [8, 256, 256]        216        True
# ______________________________________________________________________
# InstanceNorm2d       [8, 256, 256]        0          False
# ______________________________________________________________________
# LeakyReLU            [8, 256, 256]        0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 256, 256]        16         True
# ______________________________________________________________________
# MaxPool2d            [8, 128, 128]        0          False
# ______________________________________________________________________
# Conv2d               [16, 128, 128]       1,152      True
# ______________________________________________________________________
# InstanceNorm2d       [16, 128, 128]       0          False
# ______________________________________________________________________
# LeakyReLU            [16, 128, 128]       0          False
# ______________________________________________________________________
# BatchNorm2d          [16, 128, 128]       32         True
# ______________________________________________________________________
# MaxPool2d            [16, 64, 64]         0          False
# ______________________________________________________________________
# Conv2d               [32, 64, 64]         4,608      True
# ______________________________________________________________________
# InstanceNorm2d       [32, 64, 64]         0          False
# ______________________________________________________________________
# LeakyReLU            [32, 64, 64]         0          False
# ______________________________________________________________________
# BatchNorm2d          [32, 64, 64]         64         True
# ______________________________________________________________________
# Conv2d               [16, 66, 66]         512        True
# ______________________________________________________________________
# InstanceNorm2d       [16, 66, 66]         0          False
# ______________________________________________________________________
# LeakyReLU            [16, 66, 66]         0          False
# ______________________________________________________________________
# BatchNorm2d          [16, 66, 66]         32         True
# ______________________________________________________________________
# Conv2d               [32, 66, 66]         4,608      True
# ______________________________________________________________________
# InstanceNorm2d       [32, 66, 66]         0          False
# ______________________________________________________________________
# LeakyReLU            [32, 66, 66]         0          False
# ______________________________________________________________________
# BatchNorm2d          [32, 66, 66]         64         True
# ______________________________________________________________________
# MaxPool2d            [32, 33, 33]         0          False
# ______________________________________________________________________
# Conv2d               [64, 33, 33]         18,432     True
# ______________________________________________________________________
# InstanceNorm2d       [64, 33, 33]         0          False
# ______________________________________________________________________
# LeakyReLU            [64, 33, 33]         0          False
# ______________________________________________________________________
# BatchNorm2d          [64, 33, 33]         128        True
# ______________________________________________________________________
# Conv2d               [32, 35, 35]         2,048      True
# ______________________________________________________________________
# InstanceNorm2d       [32, 35, 35]         0          False
# ______________________________________________________________________
# LeakyReLU            [32, 35, 35]         0          False
# ______________________________________________________________________
# BatchNorm2d          [32, 35, 35]         64         True
# ______________________________________________________________________
# Conv2d               [64, 35, 35]         18,432     True
# ______________________________________________________________________
# InstanceNorm2d       [64, 35, 35]         0          False
# ______________________________________________________________________
# LeakyReLU            [64, 35, 35]         0          False
# ______________________________________________________________________
# BatchNorm2d          [64, 35, 35]         128        True
# ______________________________________________________________________
# MaxPool2d            [64, 17, 17]         0          False
# ______________________________________________________________________
# Conv2d               [128, 17, 17]        73,728     True
# ______________________________________________________________________
# InstanceNorm2d       [128, 17, 17]        0          False
# ______________________________________________________________________
# LeakyReLU            [128, 17, 17]        0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 17, 17]        256        True
# ______________________________________________________________________
# Conv2d               [64, 19, 19]         8,192      True
# ______________________________________________________________________
# InstanceNorm2d       [64, 19, 19]         0          False
# ______________________________________________________________________
# LeakyReLU            [64, 19, 19]         0          False
# ______________________________________________________________________
# BatchNorm2d          [64, 19, 19]         128        True
# ______________________________________________________________________
# Conv2d               [128, 19, 19]        73,728     True
# ______________________________________________________________________
# InstanceNorm2d       [128, 19, 19]        0          False
# ______________________________________________________________________
# LeakyReLU            [128, 19, 19]        0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 19, 19]        256        True
# ______________________________________________________________________
# MaxPool2d            [128, 9, 9]          0          False
# ______________________________________________________________________
# Conv2d               [256, 9, 9]          294,912    True
# ______________________________________________________________________
# InstanceNorm2d       [256, 9, 9]          0          False
# ______________________________________________________________________
# LeakyReLU            [256, 9, 9]          0          False
# ______________________________________________________________________
# BatchNorm2d          [256, 9, 9]          512        True
# ______________________________________________________________________
# Conv2d               [128, 11, 11]        32,768     True
# ______________________________________________________________________
# InstanceNorm2d       [128, 11, 11]        0          False
# ______________________________________________________________________
# LeakyReLU            [128, 11, 11]        0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 11, 11]        256        True
# ______________________________________________________________________
# Conv2d               [256, 11, 11]        294,912    True
# ______________________________________________________________________
# InstanceNorm2d       [256, 11, 11]        0          False
# ______________________________________________________________________
# LeakyReLU            [256, 11, 11]        0          False
# ______________________________________________________________________
# BatchNorm2d          [256, 11, 11]        512        True
# ______________________________________________________________________
# Conv2d               [128, 13, 13]        32,768     True
# ______________________________________________________________________
# InstanceNorm2d       [128, 13, 13]        0          False
# ______________________________________________________________________
# LeakyReLU            [128, 13, 13]        0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 13, 13]        256        True
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        294,912    True
# ______________________________________________________________________
# InstanceNorm2d       [256, 13, 13]        0          False
# ______________________________________________________________________
# LeakyReLU            [256, 13, 13]        0          False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# Conv2d               [2, 13, 13]          4,608      True
# ______________________________________________________________________
# ReLU                 [2, 13, 13]          0          False
# ______________________________________________________________________
# BatchNorm2d          [2, 13, 13]          4          True
# ______________________________________________________________________
# Flatten              [338]                0          False
# ______________________________________________________________________
# Linear               [2]                  678        True
# ______________________________________________________________________
#
# Total params: 1,164,434
# Total trainable params: 1,164,434
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : CrossEntropyLoss
# ======================================================================
# Callbacks functions applied

# %%
learn.fit_one_cycle(120, max_lr=3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.405825</td>
#       <td>0.257335</td>
#       <td>0.896000</td>
#       <td>01:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.313727</td>
#       <td>0.152827</td>
#       <td>0.944000</td>
#       <td>01:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.253985</td>
#       <td>0.123635</td>
#       <td>0.968000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.211447</td>
#       <td>0.125211</td>
#       <td>0.952000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.186116</td>
#       <td>0.165894</td>
#       <td>0.928000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.178056</td>
#       <td>0.207819</td>
#       <td>0.920000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.164141</td>
#       <td>0.110829</td>
#       <td>0.960000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.145857</td>
#       <td>0.117255</td>
#       <td>0.968000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.130054</td>
#       <td>0.116832</td>
#       <td>0.960000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.120896</td>
#       <td>0.169914</td>
#       <td>0.952000</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.131448</td>
#       <td>0.127851</td>
#       <td>0.936000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.138307</td>
#       <td>0.113955</td>
#       <td>0.984000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.125825</td>
#       <td>0.179245</td>
#       <td>0.936000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.114683</td>
#       <td>0.155491</td>
#       <td>0.960000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.110053</td>
#       <td>0.233751</td>
#       <td>0.928000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.106998</td>
#       <td>0.110024</td>
#       <td>0.976000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.133850</td>
#       <td>0.176271</td>
#       <td>0.920000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.128300</td>
#       <td>0.111697</td>
#       <td>0.960000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.119653</td>
#       <td>0.201217</td>
#       <td>0.936000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.117259</td>
#       <td>0.166471</td>
#       <td>0.936000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.116734</td>
#       <td>0.185938</td>
#       <td>0.936000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.151998</td>
#       <td>0.111081</td>
#       <td>0.968000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.145315</td>
#       <td>0.204363</td>
#       <td>0.936000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.156548</td>
#       <td>0.207498</td>
#       <td>0.920000</td>
#       <td>01:24</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.148927</td>
#       <td>0.127624</td>
#       <td>0.936000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.134810</td>
#       <td>0.116856</td>
#       <td>0.968000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.126444</td>
#       <td>0.053153</td>
#       <td>0.976000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.140641</td>
#       <td>0.230331</td>
#       <td>0.904000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.142952</td>
#       <td>0.098479</td>
#       <td>0.944000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.137687</td>
#       <td>0.173172</td>
#       <td>0.928000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.130691</td>
#       <td>0.117314</td>
#       <td>0.952000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.119417</td>
#       <td>0.098054</td>
#       <td>0.968000</td>
#       <td>01:24</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.126971</td>
#       <td>0.113141</td>
#       <td>0.920000</td>
#       <td>01:24</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.130781</td>
#       <td>0.258236</td>
#       <td>0.912000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.132121</td>
#       <td>0.092400</td>
#       <td>0.960000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.133930</td>
#       <td>0.131786</td>
#       <td>0.976000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.132144</td>
#       <td>0.158155</td>
#       <td>0.944000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.128103</td>
#       <td>0.079998</td>
#       <td>0.976000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.125032</td>
#       <td>0.384536</td>
#       <td>0.896000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.137460</td>
#       <td>0.322377</td>
#       <td>0.896000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.133664</td>
#       <td>0.154340</td>
#       <td>0.936000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.124380</td>
#       <td>0.160800</td>
#       <td>0.920000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.120551</td>
#       <td>0.234283</td>
#       <td>0.928000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.125282</td>
#       <td>0.095485</td>
#       <td>0.968000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.115737</td>
#       <td>0.094575</td>
#       <td>0.976000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.117353</td>
#       <td>0.100599</td>
#       <td>0.936000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.106982</td>
#       <td>0.188953</td>
#       <td>0.944000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.111093</td>
#       <td>0.262197</td>
#       <td>0.920000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.102474</td>
#       <td>0.184624</td>
#       <td>0.928000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.102289</td>
#       <td>0.072161</td>
#       <td>0.968000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.106735</td>
#       <td>0.110289</td>
#       <td>0.960000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.113399</td>
#       <td>0.082400</td>
#       <td>0.960000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.107296</td>
#       <td>0.170400</td>
#       <td>0.920000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.098088</td>
#       <td>0.140445</td>
#       <td>0.968000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.091911</td>
#       <td>0.156389</td>
#       <td>0.944000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.093106</td>
#       <td>0.219986</td>
#       <td>0.920000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.087587</td>
#       <td>0.069134</td>
#       <td>0.976000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.089264</td>
#       <td>0.188240</td>
#       <td>0.928000</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.075319</td>
#       <td>0.148551</td>
#       <td>0.952000</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.065938</td>
#       <td>0.091019</td>
#       <td>0.976000</td>
#       <td>0

# %%
print("Number of examples in testing:", len(data.valid_ds))
# Out:
# Number of examples in testing: 125

# %%
probs,targets = learn.get_preds(ds_type=DatasetType.Valid)

# %%
accuracy(probs,targets)
# Out:
# tensor(0.9760)

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Covid-19', 'No_findings'], 2, 500, 125)

# %%
probs = np.argmax(probs, axis=1)
correct = 0
for idx, pred in enumerate(probs):
    if pred == targets[idx]:
        correct += 1
accuracy = correct / len(probs)
print(len(probs), correct, accuracy)

from sklearn.metrics import confusion_matrix
np.set_printoptions(threshold=np.inf) 
cm1 = confusion_matrix(targets, probs)
print(cm1)

from sklearn.metrics import classification_report
y_true1 = targets
y_pred1 = probs
target_names = ['Covid-19', 'No_findings']
print(classification_report(y_true1, y_pred1, target_names=target_names))
# Out:
# 125 122 0.976
# [[ 22   3]
#  [  0 100]]
#               precision    recall  f1-score   support
#
#     Covid-19       1.00      0.88      0.94        25
#  No_findings       0.97      1.00      0.99       100
#
#     accuracy                           0.98       125
#    macro avg       0.99      0.94      0.96       125
# weighted avg       0.98      0.98      0.98       125

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
cm_fig = interp.plot_confusion_matrix(return_fig=True)
ax = cm_fig.gca()
ax.set_ylim(interp.data.c - .5, - .5);
